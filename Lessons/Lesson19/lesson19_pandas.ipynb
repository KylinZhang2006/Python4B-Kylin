# %% [markdown]
# # Let's continue to explore the IMDB Dataset.

# %% [markdown]
# ### import IMDB data and replace the PG value in the Released_Year

# %%
import pandas as pd
imdb_df = pd.read_csv('sample_data/imdb_top_1000.csv')
imdb_df_indexed = pd.read_csv('sample_data/imdb_top_1000.csv', index_col='Series_Title')

# %%
imdb_df_indexed[~imdb_df_indexed.Released_Year.str.isnumeric()]
# Out:
#                                                     Poster_Link Released_Year  \
# Series_Title
# Apollo 13     https://m.media-amazon.com/images/M/MV5BNjEzYj...            PG
#
#              Certificate  Runtime                      Genre  IMDB_Rating  \
# Series_Title
# Apollo 13              U  140 min  Adventure, Drama, History          7.6
#
#                                                        Overview  Meta_score  \
# Series_Title
# Apollo 13     NASA must devise a strategy to return Apollo 1...        77.0
#
#                 Director      Star1        Star2        Star3        Star4  \
# Series_Title
# Apollo 13     Ron Howard  Tom Hanks  Bill Paxton  Kevin Bacon  Gary Sinise
#
#               No_of_Votes        Gross
# Series_Title
# Apollo 13          269197  173,837,933

# %%
imdb_df_indexed.loc['Apollo 13','Released_Year']='1995' # give it a value

# %% [markdown]
# Then we can compare the Released_Year with int values.

# %% [markdown]
# ### Data Selection and Filtering

# %% [markdown]
# Movie from 2016:

# %%
imdb_df_indexed[imdb_df_indexed["Released_Year"].astype(int)== 2016]

# %% [markdown]
# Filter the dataset to show the movies from 2016 and all movies that had a rating more than 8.0:

# %%
imdb_df_indexed[(imdb_df_indexed["Released_Year"].astype(int)== 2016) & (imdb_df_indexed["IMDB_Rating"] >= 8.0)]

# %% [markdown]
# Let's create a new DataFrame and convert the Gross column to numeric values.

# %%
imdb_df_indexed_num_gross = pd.read_csv('sample_data/imdb_top_1000.csv', index_col='Series_Title', thousands=',')
imdb_df_indexed_num_gross.loc['Apollo 13','Released_Year']='1995' # give it a value
imdb_df_indexed_num_gross["Released_Year"] = imdb_df_indexed_num_gross["Released_Year"].astype(int)

# %%
imdb_df_indexed_num_gross.head()

# %%
imdb_df_indexed_num_gross.describe()
# Out:
#        Released_Year  IMDB_Rating  Meta_score   No_of_Votes         Gross
# count    1000.000000  1000.000000  843.000000  1.000000e+03  8.310000e+02
# mean     1991.221000     7.949300   77.971530  2.736929e+05  6.803475e+07
# std        23.285669     0.275491   12.376099  3.273727e+05  1.097500e+08
# min      1920.000000     7.600000   28.000000  2.508800e+04  1.305000e+03
# 25%      1976.000000     7.700000   70.000000  5.552625e+04  3.253559e+06
# 50%      1999.000000     7.900000   79.000000  1.385485e+05  2.353089e+07
# 75%      2009.000000     8.100000   87.000000  3.741612e+05  8.075089e+07
# max      2020.000000     9.300000  100.000000  2.343110e+06  9.366622e+08

# %% [markdown]
# Movies that released between 2016-2018 and had ratings < 8.1 but had high revenue (gross above the 75th percentile).

# %%
imdb_df_indexed_num_gross[(imdb_df_indexed_num_gross.Released_Year >= 2016)
                          & (imdb_df_indexed_num_gross.Released_Year <= 2018) 
                          & (imdb_df_indexed_num_gross.IMDB_Rating < 8.1)
                          & (imdb_df_indexed_num_gross.Gross > imdb_df_indexed_num_gross.Gross.quantile(0.75)) ]

# %% [markdown]
# ### Grouping and Sorting

# %% [markdown]
# Q1: We want to see how much gross (sum) of each director, and also the mean rating of them.

# %%
imdb_df_indexed_num_gross.head(1)
# Out:
#                                                                 Poster_Link  \
# Series_Title
# The Shawshank Redemption  https://m.media-amazon.com/images/M/MV5BMDFkYT...
#
#                           Released_Year Certificate  Runtime  Genre  \
# Series_Title
# The Shawshank Redemption           1994           A  142 min  Drama
#
#                           IMDB_Rating  \
# Series_Title
# The Shawshank Redemption          9.3
#
#                                                                    Overview  \
# Series_Title
# The Shawshank Redemption  Two imprisoned men bond over a number of years...
#
#                           Meta_score        Director        Star1  \
# Series_Title
# The Shawshank Redemption        80.0  Frank Darabont  Tim Robbins
#
#                                    Star2       Star3           Star4  \
# Series_Title
# The Shawshank Redemption  Morgan Freeman  Bob Gunton  William Sadler
#
#                           No_of_Votes       Gross
# Series_Title
# The Shawshank Redemption      2343110  28341469.0

# %%
imdb_df_indexed_num_gross.groupby('Director')[['Gross']].sum()

# %%
imdb_df_indexed_num_gross.groupby('Director')[['IMDB_Rating']].mean()

# %% [markdown]
# Q2. Who earned the most?
#
# Answer: Steven Spielberg

# %%
imdb_df_indexed_num_gross.groupby('Director')[["Gross"]].sum().sort_values(['Gross'], ascending = False)
# Out:
#                           Gross
# Director
# Steven Spielberg   2.478133e+09
# Anthony Russo      2.205039e+09
# Christopher Nolan  1.937454e+09
# James Cameron      1.748237e+09
# Peter Jackson      1.597312e+09
# ...                         ...
# Tetsuya Nakashima  0.000000e+00
# Ericson Core       0.000000e+00
# Leo McCarey        0.000000e+00
# Kinji Fukasaku     0.000000e+00
# Ömer Faruk Sorak   0.000000e+00
#
# [548 rows x 1 columns]

# %% [markdown]
# Q3. Which movies had both the highest gross and the highest rating? (use sort)

# %%
imdb_df_indexed_num_gross.sort_values(['Gross','IMDB_Rating'], ascending=False)
# Out:
#                                                                                   Poster_Link  \
# Series_Title
# Star Wars: Episode VII - The Force Awakens  https://m.media-amazon.com/images/M/MV5BOTAzOD...
# Avengers: Endgame                           https://m.media-amazon.com/images/M/MV5BMTc5MD...
# Avatar                                      https://m.media-amazon.com/images/M/MV5BMTYwOT...
# Avengers: Infinity War                      https://m.media-amazon.com/images/M/MV5BMjMxNj...
# Titanic                                     https://m.media-amazon.com/images/M/MV5BMDdmZG...
# ...                                                                                       ...
# Blowup                                      https://m.media-amazon.com/images/M/MV5BYTE4YW...
# Breakfast at Tiffany's                      https://m.media-amazon.com/images/M/MV5BNGEwMT...
# Giant                                       https://m.media-amazon.com/images/M/MV5BODk3Yj...
# Lifeboat                                    https://m.media-amazon.com/images/M/MV5BZTBmMj...
# The 39 Steps                                https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                                             Released_Year Certificate  \
# Series_Title
# Star Wars: Episode VII - The Force Awakens           2015           U
# Avengers: Endgame                                    2019          UA
# Avatar                                               2009          UA
# Avengers: Infinity War                               2018          UA
# Titanic                                              1997          UA
# ...                                                   ...         ...
# Blowup                                               1966           A
# Breakfast at Tiffany's                               1961           A
# Giant                                                1956           G
# Lifeboat                                             1944         NaN
# The 39 Steps                                         1935         NaN
#
#                                             Runtime  \
# Series_Title
# Star Wars: Episode VII - The Force Awakens  138 min
# Avengers: Endgame                           181 min
# Avatar                                      162 min
# Avengers: Infinity War                      149 min
# Titanic                                     194 min
# ...                                             ...
# Blowup                                      111 min
# Breakfast at Tiffany's                      115 min
# Giant                                       201 min
# Lifeboat                                     97 min
# The 39 Steps                                 86 min
#
#                                                                  Genre  \
# Series_Title
# Star Wars: Episode VII - The Force Awakens   Action, Adventure, Sci-Fi
# Avengers: Endgame                             Action, Adventure, Drama
# Avatar                                      Action, Adventure, Fantasy
# Avengers: Infinity War                       Action, Adventure, Sci-Fi
# Titanic                                                 Drama, Romance
# ...                                                                ...
# Blowup                                        Drama, Mystery, Thriller
# Breakfast at Tiffany's                          Comedy, Drama, Romance
# Giant                                                   Drama, Western
# Lifeboat                                                    Drama, War
# The 39 Steps                                  Crime, Mystery, Thriller
#
#                                             IMDB_Rating  \
# Series_Title
# Star Wars: Episode VII - The Force Awakens          7.9
# Avengers: Endgame                                   8.4
# Avatar                                              7.8
# Avengers: Infinity War                              8.4
# Titanic                                             7.8
# ...                                                 ...
# Blowup                                              7.6
# Breakfast at Tiffany's                              7.6
# Giant                                               7.6
# Lifeboat                                            7.6
# The 39 Steps                                        7.6
#
#                                                                                      Overview  \
# Series_Title
# Star Wars: Episode VII - The Force Awakens  As a new threat to the galaxy rises, Rey, a de...
# Avengers: Endgame                           After the devastating events of Avengers: Infi...
# Avatar                                      A paraplegic Marine dispatched to the moon Pan...
# Avengers: Infinity War                      The Avengers and their allies must be willing ...
# Titanic                                     A seventeen-year-old aristocrat falls in love ...
# ...                                                                                       ...
# Blowup                                      A fashion photographer unknowingly captures a ...
# Breakfast at Tiffany's                      A young New York socialite becomes interested ...
# Giant                                       Sprawling epic covering the life of a Texas ca...
# Lifeboat                                    Several survivors of a torpedoed merchant ship...
# The 39 Steps                                A man in London tries to help a counter-espion...
#
#                                             Meta_score  \
# Series_Title
# Star Wars: Episode VII - The Force Awakens        80.0
# Avengers: Endgame                                 78.0
# Avatar                                            83.0
# Avengers: Infinity War                            68.0
# Titanic                                           75.0
# ...                                                ...
# Blowup                                            82.0
# Breakfast at Tiffany's                            76.0
# Giant                                             84.0
# Lifeboat                                          78.0
# The 39 Steps                                      93.0
#
#                                                           Director  \
# Series_Title
# Star Wars: Episode VII - The Force Awakens             J.J. Abrams
# Avengers: Endgame                                    Anthony Russo
# Avatar                                               James Cameron
# Avengers: Infinity War                               Anthony Russo
# Titanic                                              James Cameron
# ...                                                            ...
# Blowup                                      Michelangelo Antonioni
# Breakfast at Tiffany's                               Blake Edwards
# Giant                                               George Stevens
# Lifeboat                                          Alfred Hitchcock
# The 39 Steps                                      Alfred Hitchcock
#
#                                                         Star1  \
# Series_Title
# Star Wars: Episode VII - The Force Awakens       Daisy Ridley
# Avengers: Endgame                                   Joe Russo
# Avatar                                        Sam Worthington
# Avengers: Infinity War                              Joe Russo
# Titanic                                     Leonardo DiCaprio
# ...                                                       ...
# Blowup                                         David Hemmings
# Breakfast at Tiffany's                         Audrey Hepburn
# Giant                                        Elizabeth Taylor
# Lifeboat                                    Tallulah Bankhead
# The 39 Steps                                     Robert Donat
#
#                                                         Star2  \
# Series_Title
# Star Wars: Episode VII - The Force Awakens        John Boyega
# Avengers: Endgame                           Robert Downey Jr.
# Avatar                                            Zoe Saldana
# Avengers: Infinity War                      Robert Downey Jr.
# Titanic                                          Kate Winslet
# ...                                                       ...
# Blowup                                       Vanessa Redgrave
# Breakfast at Tiffany's                         George Peppard
# Giant                                             Rock Hudson
# Lifeboat                                          John Hodiak
# The 39 Steps                                Madeleine Carroll
#
#                                                        Star3  \
# Series_Title
# Star Wars: Episode VII - The Force Awakens       Oscar Isaac
# Avengers: Endgame                                Chris Evans
# Avatar                                      Sigourney Weaver
# Avengers: Infinity War                       Chris Hemsworth
# Titanic                                           Billy Zane
# ...                                                      ...
# Blowup                                           Sarah Miles
# Breakfast at Tiffany's                         Patricia Neal
# Giant                                             James Dean
# Lifeboat                                       Walter Slezak
# The 39 Steps                                  Lucie Mannheim
#
#                                                          Star4  No_of_Votes  \
# Series_Title
# Star Wars: Episode VII - The Force Awakens    Domhnall Gleeson       860823
# Avengers: Endgame                                 Mark Ruffalo       809955
# Avatar                                      Michelle Rodriguez      1118998
# Avengers: Infinity War                            Mark Ruffalo       834477
# Titanic                                            Kathy Bates      1046089
# ...                                                        ...          ...
# Blowup                                             John Castle        56513
# Breakfast at Tiffany's                             Buddy Ebsen       166544
# Giant                                            Carroll Baker        34075
# Lifeboat                                        William Bendix        26471
# The 39 Steps                                    Godfrey Tearle        51853
#
#                                                   Gross
# Series_Title
# Star Wars: Episode VII - The Force Awakens  936662225.0
# Avengers: Endgame                           858373000.0
# Avatar                                      760507625.0
# Avengers: Infinity War                      678815482.0
# Titanic                                     659325379.0
# ...                                                 ...
# Blowup                                              NaN
# Breakfast at Tiffany's                              NaN
# Giant                                               NaN
# Lifeboat                                            NaN
# The 39 Steps                                        NaN
#
# [1000 rows x 15 columns]

# %% [markdown]
# ### Missing values

# %%
import numpy as np
import pandas as pd

array_with_None = np.array([0, None, 2, 3])
print(array_with_None.dtype)
print(array_with_None)
# Out:
# object
# [0 None 2 3]

# %%
array_with_NaN = np.array([0, np.nan, 2, 3])
print(array_with_NaN.dtype)
print(array_with_NaN)
# Out:
# float64
# [ 0. nan  2.  3.]

# %%
print(array_with_None.sum()) # it will fail with None

# %%
print(array_with_NaN.sum()) # it will calculate, but return nan
# Out:
# nan

# %%
imdb_df_indexed_num_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, The Shawshank Redemption to The 39 Steps
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Released_Year  1000 non-null   int64
#  2   Certificate    899 non-null    object
#  3   Runtime        1000 non-null   object
#  4   Genre          1000 non-null   object
#  5   IMDB_Rating    1000 non-null   float64
#  6   Overview       1000 non-null   object
#  7   Meta_score     843 non-null    float64
#  8   Director       1000 non-null   object
#  9   Star1          1000 non-null   object
#  10  Star2          1000 non-null   object
#  11  Star3          1000 non-null   object
#  12  Star4          1000 non-null   object
#  13  No_of_Votes    1000 non-null   int64
#  14  Gross          831 non-null    float64
# dtypes: float64(3), int64(2), object(10)
# memory usage: 157.3+ KB

# %%
imdb_df_indexed_num_gross.isnull()
# Out:
#                           Poster_Link  Released_Year  Certificate  Runtime  \
# Series_Title
# The Shawshank Redemption        False          False        False    False
# The Godfather                   False          False        False    False
# The Dark Knight                 False          False        False    False
# The Godfather: Part II          False          False        False    False
# 12 Angry Men                    False          False        False    False
# ...                               ...            ...          ...      ...
# Breakfast at Tiffany's          False          False        False    False
# Giant                           False          False        False    False
# From Here to Eternity           False          False        False    False
# Lifeboat                        False          False         True    False
# The 39 Steps                    False          False         True    False
#
#                           Genre  IMDB_Rating  Overview  Meta_score  Director  \
# Series_Title
# The Shawshank Redemption  False        False     False       False     False
# The Godfather             False        False     False       False     False
# The Dark Knight           False        False     False       False     False
# The Godfather: Part II    False        False     False       False     False
# 12 Angry Men              False        False     False       False     False
# ...                         ...          ...       ...         ...       ...
# Breakfast at Tiffany's    False        False     False       False     False
# Giant                     False        False     False       False     False
# From Here to Eternity     False        False     False       False     False
# Lifeboat                  False        False     False       False     False
# The 39 Steps              False        False     False       False     False
#
#                           Star1  Star2  Star3  Star4  No_of_Votes  Gross
# Series_Title
# The Shawshank Redemption  False  False  False  False        False  False
# The Godfather             False  False  False  False        False  False
# The Dark Knight           False  False  False  False        False  False
# The Godfather: Part II    False  False  False  False        False  False
# 12 Angry Men              False  False  False  False        False  False
# ...                         ...    ...    ...    ...          ...    ...
# Breakfast at Tiffany's    False  False  False  False        False   True
# Giant                     False  False  False  False        False   True
# From Here to Eternity     False  False  False  False        False  False
# Lifeboat                  False  False  False  False        False   True
# The 39 Steps              False  False  False  False        False   True
#
# [1000 rows x 15 columns]

# %%
imdb_df_indexed_num_gross.isnull().sum() # it will check how many nulls in each column
# Out:
# Poster_Link        0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %% [markdown]
# drop the null values

# %%
imdb_df_indexed_num_gross.dropna() # it will drop all rows with any missing values

# %%
imdb_df_indexed_num_gross.dropna(axis = 1) # it will drop all columns with any missing values

# %% [markdown]
# But doing this, we lost lots of data! If we drop rows, we lose more than 200 movies. If we drop columns, we lose useful info like gross. We only want to drop the values if it's super unuseful.

# %%
imdb_df_indexed_num_gross.dropna(axis='rows', thresh=13) #thresh to specify a minium number of non-null values

# %% [markdown]
# Reference: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html

# %%
imdb_df_indexed_num_gross.dropna(axis='columns',how='all') # columns will be dropped if all the values are missing
# Out:
#                                                                 Poster_Link  \
# Series_Title
# The Shawshank Redemption  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# The Godfather             https://m.media-amazon.com/images/M/MV5BM2MyNj...
# The Dark Knight           https://m.media-amazon.com/images/M/MV5BMTMxNT...
# The Godfather: Part II    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 12 Angry Men              https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ...                                                                     ...
# Breakfast at Tiffany's    https://m.media-amazon.com/images/M/MV5BNGEwMT...
# Giant                     https://m.media-amazon.com/images/M/MV5BODk3Yj...
# From Here to Eternity     https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# Lifeboat                  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# The 39 Steps              https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                           Released_Year  Runtime                     Genre  \
# Series_Title
# The Shawshank Redemption           1994  142 min                     Drama
# The Godfather                      1972  175 min              Crime, Drama
# The Dark Knight                    2008  152 min      Action, Crime, Drama
# The Godfather: Part II             1974  202 min              Crime, Drama
# 12 Angry Men                       1957   96 min              Crime, Drama
# ...                                 ...      ...                       ...
# Breakfast at Tiffany's             1961  115 min    Comedy, Drama, Romance
# Giant                              1956  201 min            Drama, Western
# From Here to Eternity              1953  118 min       Drama, Romance, War
# Lifeboat                           1944   97 min                Drama, War
# The 39 Steps                       1935   86 min  Crime, Mystery, Thriller
#
#                           IMDB_Rating  \
# Series_Title
# The Shawshank Redemption          9.3
# The Godfather                     9.2
# The Dark Knight                   9.0
# The Godfather: Part II            9.0
# 12 Angry Men                      9.0
# ...                               ...
# Breakfast at Tiffany's            7.6
# Giant                             7.6
# From Here to Eternity             7.6
# Lifeboat                          7.6
# The 39 Steps                      7.6
#
#                                                                    Overview  \
# Series_Title
# The Shawshank Redemption  Two imprisoned men bond over a number of years...
# The Godfather             An organized crime dynasty's aging patriarch t...
# The Dark Knight           When the menace known as the Joker wreaks havo...
# The Godfather: Part II    The early life and career of Vito Corleone in ...
# 12 Angry Men              A jury holdout attempts to prevent a miscarria...
# ...                                                                     ...
# Breakfast at Tiffany's    A young New York socialite becomes interested ...
# Giant                     Sprawling epic covering the life of a Texas ca...
# From Here to Eternity     In Hawaii in 1941, a private is cruelly punish...
# Lifeboat                  Several survivors of a torpedoed merchant ship...
# The 39 Steps              A man in London tries to help a counter-espion...
#
#                                       Director              Star1  \
# Series_Title
# The Shawshank Redemption        Frank Darabont        Tim Robbins
# The Godfather             Francis Ford Coppola      Marlon Brando
# The Dark Knight              Christopher Nolan     Christian Bale
# The Godfather: Part II    Francis Ford Coppola          Al Pacino
# 12 Angry Men                      Sidney Lumet        Henry Fonda
# ...                                        ...                ...
# Breakfast at Tiffany's           Blake Edwards     Audrey Hepburn
# Giant                           George Stevens   Elizabeth Taylor
# From Here to Eternity           Fred Zinnemann     Burt Lancaster
# Lifeboat                      Alfred Hitchcock  Tallulah Bankhead
# The 39 Steps                  Alfred Hitchcock       Robert Donat
#
#                                       Star2           Star3           Star4  \
# Series_Title
# The Shawshank Redemption     Morgan Freeman      Bob Gunton  William Sadler
# The Godfather                     Al Pacino      James Caan    Diane Keaton
# The Dark Knight                Heath Ledger   Aaron Eckhart   Michael Caine
# The Godfather: Part II       Robert De Niro   Robert Duvall    Diane Keaton
# 12 Angry Men                    Lee J. Cobb   Martin Balsam    John Fiedler
# ...                                     ...             ...             ...
# Breakfast at Tiffany's       George Peppard   Patricia Neal     Buddy Ebsen
# Giant                           Rock Hudson      James Dean   Carroll Baker
# From Here to Eternity      Montgomery Clift    Deborah Kerr      Donna Reed
# Lifeboat                        John Hodiak   Walter Slezak  William Bendix
# The 39 Steps              Madeleine Carroll  Lucie Mannheim  Godfrey Tearle
#
#                           No_of_Votes
# Series_Title
# The Shawshank Redemption      2343110
# The Godfather                 1620367
# The Dark Knight               2303232
# The Godfather: Part II        1129952
# 12 Angry Men                   689845
# ...                               ...
# Breakfast at Tiffany's         166544
# Giant                           34075
# From Here to Eternity           43374
# Lifeboat                        26471
# The 39 Steps                    51853
#
# [1000 rows x 12 columns]
